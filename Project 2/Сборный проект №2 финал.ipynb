# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Артур, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам аналитика. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
# Я не смогу принять проект, если в нём будет хотя бы одна критичная ошибка или несколько некритичных ошибок - тогда проект нужно будет немного доработать. Но это нестрашно - я обязательно дам тебе подсказку или укажу верное направление.
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# # Восстановление золота из руды
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# Подготовить данные;
#
# Провести исследовательский анализ данных;
#
# Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам pandas, matplotlib и sklearn. Вам поможет их документация.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %% [markdown]
# # 1  Подготовка данных

# %%
# Загружаем библиотеки
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
#import sweetviz as sv

from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

from sklearn.model_selection import ( cross_val_score ) # валидация  
# для приведение к одному масштабу (масштабирование)
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import (mean_absolute_error, 
                             f1_score, # это возможно не надо
                             accuracy_score) # это возможно не надо
from sklearn.dummy import DummyRegressor

from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import make_pipeline
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

#from sklearn.utils import shuffle # для перемешевания данных
#from scipy import stats as st 
#from sklearn.metrics import mean_squared_error, r2_score 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Я вижу, исполнение твоего кода начинается в ячейке с номером, который отличается от единицы. Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
#
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
# Важно также убедиться, что все ячейки проекта исполнились - можно просто пролистать работу до конца и убедиться, что последняя ячейка исполнена. Такая проверка поможет тебе убедиться, что твоё решение будет должным образом воспроизведено во время ревью или во время передачи его заказчику - это очень важный этап, пренебрегать которым не стоит:)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Ты импортируешь библиотеки и модули, которые не используешь в проекте - так делать не стоит, так как ты забиваешь окружение лишними  инструментами.
#
# В блоке импорта стоит оставить только то, что реально используется в проекте.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Понял, обычно я перекопирую из своих предыдущих работ чтобы копить их в одном месте.
# Удалил лишнее, оставил только то что нужно и закомментировал то что возможно пригодится.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Окей, отлично!

# %% [markdown]
# ## Описание данных
#
# **Признаки**
#
# Технологический процесс
# -	Rougher feed — исходное сырье
# -	Rougher additions (или reagent additions) — флотационные реагенты (это вещество или соединение, добавленное в систему для того, чтобы вызвать химическую реакцию):
#
# Xanthate, Sulphate, Depressant
# -	Xanthate — ксантогенат (промотер, или активатор флотации);
# -	Sulphate — сульфат (на данном производстве сульфид натрия);
# -	Depressant — депрессант (силикат натрия).
#
#
# -	Rougher process (англ. «грубый процесс») — флотация
# -	Rougher tails — отвальные хвосты
# -	Float banks — флотационная установка
# -	Cleaner process — очистка
# -	Rougher Au — черновой концентрат золота
# -	Final Au — финальный концентрат золота
#
#
# Параметры этапов
# -	air amount — объём воздуха
# -	fluid levels — уровень жидкости
# -	feed size — размер гранул сырья
# -	feed rate — скорость подачи
#
#
# Наименование признаков должно быть такое:
# [этап].[тип_параметра].[название_параметра]
#
# Пример: rougher.input.feed_ag
#
# Возможные значения для блока [этап]:
# -	rougher — флотация
# -	primary_cleaner — первичная очистка
# -	secondary_cleaner — вторичная очистка
# -	final — финальные характеристики
#
#
# Возможные значения для блока [тип_параметра]:
# -	input — параметры сырья
# -   output — параметры продукта
# -	state — параметры, характеризующие текущее состояние этапа
# -	calculation — расчётные характеристики

# %%
# загрузим данные
try:
    df_full = pd.read_csv('/datasets/gold_industry_full.csv')
except:
    df_full = pd.read_csv('gold_industry_full.csv')
    
try:
    df_test = pd.read_csv('/datasets/gold_industry_test.csv')
except:
    df_test = pd.read_csv('gold_industry_test.csv')
    
try:
    df_train = pd.read_csv('/datasets/gold_industry_train.csv')
except:
    df_train = pd.read_csv('gold_industry_train.csv')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Данные загрузили - отлично!
#
# Здорово, что ты используешь конструкцию ``try-except`` для путей файлов. Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
#
# Также на этапе считывания данных задать индекс-столбец- за это действие отвечает параметр `index_col`.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Не нужно делать блок `try-except` на каждую таблицу - достаточно поместить в блок `try` загрузку всех таблиц из одного источника, в `except` - из другого.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Так не вышло
#
# `try:
#     df_full = pd.read_csv('/datasets/gold_industry_full.csv')
#     df_test = pd.read_csv('/datasets/gold_industry_test.csv'
#     df_train = pd.read_csv('/datasets/gold_industry_train.csv')
# except:
#     df_test = pd.read_csv('gold_industry_test.csv')
#     df_full = pd.read_csv('gold_industry_full.csv')
#     df_train = pd.read_csv('gold_industry_train.csv')`
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Обрати внимание, что в блоке `try` для `df_test` не хватает скобочки в конце - поэтому не вышло:) А так в целом вышло хорошо.

# %%
#report = sv.analyze([df_full, " Permit Logs"])
#report.show_notebook() 
# по совету ревьюера предыдущего проекта 
#(долгая штука и английский пока не так удобен)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Совет хороший:
# - штука достаточно тялёлая;
# - будет сложно интерпретироваться бизнес-заказчиком - выглядит как чудная и непонятная вундервафля без акцентов, разбиайся сам - бизнес так не любит.

# %%
display(df_full.info())
df_full.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   rougher.input.feed_au                               19439 non-null  float64
#  2   rougher.input.feed_ag                               19439 non-null  float64
#  3   rougher.input.feed_pb                               19339 non-null  float64
#  4   rougher.input.feed_sol                              19340 non-null  float64
#  5   rougher.input.feed_rate                             19428 non-null  float64
#  6   rougher.input.feed_size                             19294 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   19405 non-null  float64
# ...

# %%
display(df_test.info())
df_test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4860 entries, 0 to 4859
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        4860 non-null   object
#  1   rougher.input.feed_au                       4860 non-null   float64
#  2   rougher.input.feed_ag                       4860 non-null   float64
#  3   rougher.input.feed_pb                       4832 non-null   float64
#  4   rougher.input.feed_sol                      4838 non-null   float64
#  5   rougher.input.feed_rate                     4856 non-null   float64
#  6   rougher.input.feed_size                     4816 non-null   float64
#  7   rougher.input.floatbank10_sulfate           4857 non-null   float64
#  8   rougher.input.floatbank10_xanthate          4859 non-null   float64
# ...

# %%
display(df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14579 entries, 0 to 14578
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14579 non-null  object
#  1   rougher.input.feed_au                               14579 non-null  float64
#  2   rougher.input.feed_ag                               14579 non-null  float64
#  3   rougher.input.feed_pb                               14507 non-null  float64
#  4   rougher.input.feed_sol                              14502 non-null  float64
#  5   rougher.input.feed_rate                             14572 non-null  float64
#  6   rougher.input.feed_size                             14478 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   14548 non-null  float64
# ...

# %%
display(df_full.describe())
display(df_test.describe())
df_train.describe()
# Out:
#        rougher.input.feed_au  rougher.input.feed_ag  rougher.input.feed_pb  \
# count           19439.000000           19439.000000           19339.000000
# mean                8.266097               8.794927               3.598085
# std                 1.955092               1.936847               1.049486
# min                 0.010000               0.010000               0.010000
# 25%                 6.854384               7.237967               2.887280
# 50%                 8.125839               8.593574               3.534895
# 75%                 9.769917              10.213771               4.244161
# max                13.731330              14.596026               7.142594
#
#        rougher.input.feed_sol  rougher.input.feed_rate  \
# count            19340.000000             19428.000000
# mean                36.695114               478.320042
# std                  5.145445               105.373758
# min                  0.010000                 0.002986
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Данные осмотрели - отлично!

# %% [markdown]
# ### Проверим на наличие дубликатов

# %%
display(df_full.duplicated().sum())
display(df_test.duplicated().sum())
df_train.duplicated().sum()
# Out:
# 0
# 0
# 0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Дубликатов нет.

# %% [markdown]
# **Подитог**
#
# - Явные дубликаты не обнаружены
# - Очень большие датасеты по своему объему, количеству колонок, неудобны для восприятия и анализа пропусков.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть небольшой подитог - отлично, что не забываешь про них:)

# %% [markdown]
# ### 1.2 Рассчитаем эффективность обогащения чернового концентрата rougher.output.recovery (MAE)

# %% [markdown]
# Найдите MAE между вашими расчётами и значением признака.
#
# Эффективность обогащения рассчитывается по формуле:
#
#
#  ![image.png](attachment:image.png)
# где:
# - C — доля золота в концентрате после флотации/очистки; (здесь нужно найти долю золота после первичной и вторичной  очистки)
# -	F — доля золота в сырье/концентрате до флотации/очистки;
# -	T — доля золота в отвальных хвостах после флотации/очистки.

# %% [markdown]
# 1.	эффективность обогащения чернового концентрата rougher.output.recovery;
# 2.	эффективность обогащения финального концентрата final.output.recovery.

# %% [markdown]
# ### Проверим формулу вычисления эффективности обогащения чернового концентрата

# %% [markdown]
# ### Признаки по черновой обработке
#
# - rougher.output.concentrate_au  (C) # (концетрация золота после черновой обработки
# - rougher.input.feed_au # (F) содержание золота в сырьевом материале,  поступающем на первичную (черновую) обработку
# - ИЛИ  доля золота в золотосодержащей руде до обработки
# - rougher.output.tail_au (T) остатки вещества после первичной (черновой) обработки золота в хвосте
# - rougher.output.recovery показатель эффективности обогащения чернового концентрата ;

# %%
c = df_train['rougher.output.concentrate_au'] # (C)
# концетрация золота после черновой обработки 

f = df_train['rougher.input.feed_au'] # (F)
# содержание золота в сырьевом материале, 
# поступающем на первичную (черновую) обработку


t = df_train['rougher.output.tail_au'] # (T)
# остатки вещества золота в хвосте

# показатель эффективность обогащения чернового концентрата rougher.output.recovery;
input_recovery = df_train['rougher.output.recovery']


calculated_recovery = (c * (f - t) / (f * (c - t)))*100
print('Среднее значение в ручную рассчитанного показателя эффективности обогащения:'\
      , calculated_recovery.mean())
print('Среднее значение показателя эффективности обогощения:',\
      input_recovery.mean())
print('Эффективность обогащения чернового концентрата', calculated_recovery)
print('Абсолютная средняя ошибка, MAE =', mean_absolute_error(input_recovery, calculated_recovery))
# Out:
# Среднее значение в ручную рассчитанного показателя эффективности обогащения: 82.52119968211336
# Среднее значение показателя эффективности обогощения: 82.52119968211336
# Эффективность обогащения чернового концентрата 0        87.107763
# 1        86.843261
# 2        86.842308
# 3        87.226430
# 4        86.688794
#            ...
# 14574    87.684717
# 14575    90.677361
# 14576    89.574376
# 14577    87.724007
# 14578    88.890579
# Length: 14579, dtype: float64
# Абсолютная средняя ошибка, MAE = 9.83758577644259e-15

# %% [markdown]
# MAE имеет очень малое отклонение, максимально приближенное к 0 - это значит, что в ручную рассчитанный показатель эффективности обогащения чернового концентрата rougher.output.recovery совпадает с данными из столбца.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Оценили `MAE` между исходным и расчётным значением эффективности обогащения и убедились, что эффективность обогащения рассчитана правильно - отлично!
# </div>

# %% [markdown]
# ###  Проанализируем признаки, недоступные в тестовой выборке

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий: </b>Просьба подсказать как улучшить код ниже
# </div>

# %%
for column, column1 in zip(df_train.columns, df_test.columns):
    if column1 not in column:
        print(column)
# цикл сработал не до конца правильно, некоторые признаки проанализированы в ручную
# Out:
# rougher.calculation.sulfate_to_au_concentrate
# rougher.calculation.floatbank10_sulfate_to_au_feed
# rougher.calculation.floatbank11_sulfate_to_au_feed
# rougher.calculation.au_pb_ratio
# rougher.output.concentrate_au
# rougher.output.concentrate_ag
# rougher.output.concentrate_pb
# rougher.output.concentrate_sol
# rougher.output.recovery
# rougher.output.tail_au
# rougher.output.tail_ag
# rougher.output.tail_pb
# rougher.output.tail_sol
# primary_cleaner.input.sulfate
# primary_cleaner.input.depressant
# primary_cleaner.input.feed_size
# primary_cleaner.input.xanthate
# primary_cleaner.state.floatbank8_a_air
# primary_cleaner.state.floatbank8_a_level
# primary_cleaner.state.floatbank8_b_air
# primary_cleaner.state.floatbank8_b_level
# primary_cleaner.state.floatbank8_c_air
# primary_cleaner.state.floatbank8_c_level
# primary_cleaner.state.floatbank8_d_air
# primary_cleaner.state.floatbank8_d_level
# primary_cleaner.output.concentrate_au
# primary_cleaner.output.concentrate_ag
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Было бы удобнее через множества - см. ниже.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Все гениальное просто) а в цикле если? или не имеет смысла заморачиваться?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Думаю, что нет - итерирование обычно занимает больше памяти/ресурсов. Но если очень хочется именно циклом - есть классная штука `list comprehension` - см. ниже.

# %%
[train_col for train_col in df_train.columns if train_col not in df_test.columns]
# Out:
# ['rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
#  'rougher.output.tail_au',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_pb',
#  'rougher.output.tail_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'secondary_cleaner.output.tail_au',
#  'secondary_cleaner.output.tail_ag',
#  'secondary_cleaner.output.tail_pb',
#  'secondary_cleaner.output.tail_sol',
# ...

# %%
set(df_train.columns) - set(df_test.columns)
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# **Подитог**:
#
# Исходя из ТЗ некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые есть в обучающей.
#
#
# Cтолбцы rougher.calculation, rougher.output, primary_cleaner.output.concentrate, primary_cleaner.output.tail_au, secondary_cleaner.output и  final.output отсутсвуют в тестовой выборке, так как заполняются после тех. процессов.
#
# Они относятся к типу float т.е. числовые.
#
# - rougher.calculation - это вероятно название какой-то процедуры или расчета, связанного с извлечением "золота" из руды.
# -  primary_cleaner.output.concentrate - это  означает содержание "золота" в концентрате, который получается на выходе из первичного этапа очистки.
# - rougher.output - содержит информацию о содержании золота в продукте после флотации (этап обогащения руды)
#
# - primary_cleaner.output.tail_au - отображает количество золота, которое не было извлечено в результате первичной очистки и осталось в отходах.
#
# - secondary_cleaner.output -  это выходные данные вторичного этапа очистки в процессе обогащения руды
# - final.output.concentrate_au - это финальная характеристика выходного концентрата золота
#
#
#
# - rougher — флотация
# - primary_cleaner — первичная очистка
# - secondary_cleaner — вторичная очистка
# - calculation - расчётные характеристики
#
#
#
#
#
# - **Также не забываем что в тестовом наборе нет целевых признаков**.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Проанализировали разницу в признаках между выборками. Вывод верный: действительно, в тестовой выборке присутствуют только те параметры техпроцесса, которые мы можем получить непосредственно в ходе процесса или по его окончании.
# </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий: </b> Код не срабатывал должным обарзом и в трейне удалялось больше 3000 строк, хотя там столько пропусков не было, с чем связано?
#
# Или происходит удаления колонок с 0-вым значением?
#
# Пришлось заполнить...
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> `dropna()` по умолчанию удаляет строки, где есть хоть один пропуск - если ниже обратить внимание на то, сколько суммарно пропусков у нас есть по строкам, столько и получается - чуть больше 3к. На самом деле, если размер выборки после удаления пропусков остаётся достаточно большим, то пропуски лучше удалять - любая импутация сопряжена с риском ошибки.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Мне не пришло в голову, что каждый признак может на разных строках иметь NAN
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Век живи - век учись, что называется:)

# %%
df_train.isna().sum().sum()
# Out:
# 3050

# %%
# Количество пропусков в данных менее 3%
# для дальнейшей работы будет правильнее их удалить
# df_train = df_train.dropna()
# df_test = df_test.dropna()

# %%
#заполним пропуски методом 'ffill'
df_train = df_train.sort_values(ascending=True, by='date').fillna(method='ffill')
df_test = df_test.sort_values(ascending=True, by='date').fillna(method='ffill')
df_full = df_full.sort_values(ascending=True, by='date').fillna(method='ffill')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Обработали пропуски с помощью стратегии заполнения `forward fill` - отлично!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# В комментариях важно пояснить, почему была выбрана именно эта стратегия работы с пропусками.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Потому что каждая строка имеет дату и время , то есть они последовательно идут друг за другом, поэтому данный метод подходит.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Верно. Ещё по условию проекта знаем, что соседние наблюдения похожи.

# %%
df_train.reset_index(drop= True, inplace=True)
df_test.reset_index(drop= True, inplace=True)
df_full.reset_index(drop= True, inplace=True)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В принципе необязательно, но не ошибка - окей:)

# %% [markdown]
# ### Вывод:
# Данные разобраны, не имеют явных дубликатов и не имеют пропусков.
#
# Можно приступать к следующему этапу.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Небольшой промежуточный вывод - отлично!

# %% [markdown]
# # 2  Анализ данных

# %% [markdown]
# ## 2.1. Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате. Какие особенности имеют распределения? Опишите выводы.

# %%
display(df_train['rougher.input.feed_au'].mean())
display(df_train['rougher.output.concentrate_au'].mean())
display(df_train['primary_cleaner.output.concentrate_au'].mean())
display(df_train['final.output.concentrate_au'].mean())
# Out:
# 8.352940920963524
# 19.71747030146708
# 32.00753497230735
# 43.97949926726813

# %%
# Золото
plt.figure(figsize=[12,8])

plt.hist(df_train['rougher.input.feed_au'], bins=100, label = 'Концетрация в сырье', alpha=.5)
plt.hist(df_train['rougher.output.concentrate_au'], bins=100, \
         label = 'Концетрация при черновой обработке', alpha=.5)
plt.hist(df_train['primary_cleaner.output.concentrate_au'], bins=100, \
         label = 'Концетрация после первой очистки', alpha=.5)
plt.hist(df_train['final.output.concentrate_au'], bins=100, \
         label = 'Концетрация в финальном результате', alpha=.5)

plt.xlim([0, 60])
plt.ylim([0, 1300])

plt.xlabel("Концентрация (вес) золота на различных этапах флотации")
plt.ylabel("Количество одинаковых результатов")

plt.legend(loc='upper left', fontsize='xx-large')

plt.title("Гистограмма распределения концентрации золота")
plt.show()

# %% [markdown]
# Во всех распределениях присутствует пик около нулевого значения. Он очень далек от общего распределения.

# %% [markdown]
# **Подитог**
#
# На гистограмме видим что концентарция золота с каждым этапом планомерно растет. То есть с помощью флотации мы обогащаем золото, показатель вырос с 5-10 у.е. до 40-50 у.е.

# %%
# удаляем аномальные значения
df_train = df_train.drop(df_train[df_train['rougher.output.concentrate_au'] == 0].index)
df_train[df_train['rougher.output.concentrate_au'] == 0].head()
# Out:
# Empty DataFrame
# ...

# %%
# Серебро
plt.figure(figsize=[8,8])

plt.hist(df_train['rougher.input.feed_ag'], bins=100, label = 'Концетрация в сырье', alpha=.9)
plt.hist(df_train['final.output.concentrate_ag'], bins=100, \
         label = 'Концетрация в финальном результате', alpha=.5)
plt.hist(df_train['rougher.output.concentrate_ag'], bins=100, \
          label = 'Концетрация при черновой обработке', alpha=.5)
plt.hist(df_train['primary_cleaner.output.concentrate_ag'], bins=100, \
          label = 'Концетрация после первой очистки', alpha=.8)


plt.xlabel("Концентрация (вес) серебра на различных этапах флотации")
plt.ylabel("Количество одинаковых результатов")

plt.legend(loc='upper right', fontsize='medium')

plt.title("Гистограмма распределения концентрации серебра")
plt.show()

# %%
df_train = df_train.drop(df_train[df_train['final.output.concentrate_ag'] == 0].index)
df_train[df_train['final.output.concentrate_ag'] == 0].head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# **Подитог**
#
# На гистограмме видно как сначала концентрация серебра растет от диапазонов с 5-10 до 10-15 на этапе черновой очистки, и начниая с первой очистки до финальной, концетрация падает до 3-6 у. ед.

# %%
df_train = df_train.drop(df_train[df_train['primary_cleaner.output.concentrate_ag'] < 0.5].index)
df_train[df_train['primary_cleaner.output.concentrate_ag'] == 0].head()
# Out:
# Empty DataFrame
# ...

# %%
# свинец
plt.figure(figsize=[12,8])

plt.hist(df_train['rougher.input.feed_pb'], bins=100, label = 'Концетрация в сырье', alpha=.5)
plt.hist(df_train['rougher.output.concentrate_pb'], bins=100, \
         label = 'Концетрация при черновой обработке', alpha=.5)
plt.hist(df_train['primary_cleaner.output.concentrate_pb'], bins=100, \
         label = 'Концетрация после первой очистки', alpha=.4)
plt.hist(df_train['final.output.concentrate_pb'], bins=100, \
         label = 'Концетрация в финальном результате', alpha=.8)



plt.xlabel("Концентрация (вес) свинца на различных этапах флотации")
plt.ylabel("Количество одинаковых результатов")

plt.legend(loc='upper left', fontsize='large')

plt.title("Гистограмма распределения концентрации свинца")
plt.show()

# %%
# удаляем выбросы у нулевых значений
df_train = df_train.drop(df_train[df_train['primary_cleaner.output.concentrate_pb'] < 0.5].index)
df_train = df_train.drop(df_train[df_train['final.output.concentrate_pb'] == 0].index)
df_train[df_train['primary_cleaner.output.concentrate_pb'] == 0].head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# **Подитог**
#
# На гистограмме видно как сначала концентрация свинца растет от диапазонов с 2,5 - 5 у.е. до 7 - 10 у.е. на этапе черновой очистки, и далее остается неизменной.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследована концентрация металлов на разных стадиях обработки, проанализирована динамика концентрации в зависимости от этапа техпроцесса - отлично, тут всё верно.
#
# Круто, что на графике были отмечены и удалены нулевые значения - это действительно аномалия, подлежащая удалению.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# После золота визуализация организована не очень оптимально: ты на графике отображаешь по две концентрации, при этом настраивая `xlim` - не очень удобно для восприятия. Стоит сделать по примеру золота - все этапы на одном графике, без `xlim`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Я изначально так сделал как в золоте, но поскольку у них примерно один диапазон был и все сливалось я убрал и сделал по 2. Вернул - без xlim
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ## 2.2. Сравним распределения размеров гранул исходного сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %%
plt.figure(figsize=(12,8)) 
sns.kdeplot(
   data=df_train['rougher.input.feed_size'], legend = True,
    label = 'Размер гранул исходного сырья на обучающей выборке',
   fill=False, common_norm=False, palette="crest",
   alpha=.5, gridsize = 600, linewidth=2
)

sns.kdeplot(
   data=df_test['rougher.input.feed_size'],legend = True,
   label = 'Размер гранул исходного сырья на тестовой выборке',
   gridsize = 600,
   fill=False, common_norm=False, palette="crest",
   alpha=.5, linewidth=2
)

plt.xlabel('Размер гранул сырья в двух выборках')
plt.xlabel("Размер гранул сырья")
plt.ylabel("Плотность распределения")
plt.legend(loc='upper right', fontsize='x-large')
plt.title("Гистограмма распределения гранул сырья перед флотацией")
plt.show()

# %% [markdown]
# **Поидтог**
#
# В целом видем нормальное распеделение со смещение влево, распределения напоминают друг друга, просто с разным количеством элементов, оценка модели будет правильной.
# Также после 100-150 видим много выбросов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Сравнили размеры гранул сырья на обучающей и тестовой выборках для этапа `rougher.input.feed_size` - отлично, распределения между выборками действительно схожи, следовательно модель будет корректно работать.
#
# Чуть более интересным решением было бы использование статистического теста (например, `ttest`) для сравнения распределений в выборках.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Здесь про ttest можно поподробнее
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> `ttest` позволяет сравнить равенство средних в двух выборках - можем сделать вывод о схожести распределения, но уже не графически, а статистически.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Здесь мы имеем дело с непрерывной величиной - для анализа её распределения стоит использовать график распределения плотности `kde` (например, `sns.kdeplot`) вместо обычной гистограммы, она позволяет нивелировать разницу в размерах выборок при анализе распределений. Обрати также внимание, что при использовании `kdeplot()` по оси Y будет уже не частота значений, а плотность распределения.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Вроде сделал
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ## 2.3. Исследуем суммарную концентрацию металлов на разных стадиях: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.

# %% [markdown]
# Подготовим столбцы с концентрациями всех материалов в обучающей выборке по этапам и построим гистограмму.

# %%
rougher_input_concentrate_sum = (df_train['rougher.input.feed_au'] + 
                                 df_train['rougher.input.feed_ag'] + 
                                 df_train['rougher.input.feed_pb'] )

rougher_output_concentrate_sum = (df_train['rougher.output.concentrate_au'] + 
                                  df_train['rougher.output.concentrate_ag'] + 
                                  df_train['rougher.output.concentrate_pb'] )


primary_cleaner_output_concentrate_sum = (df_train['primary_cleaner.output.concentrate_au'] + 
                                          df_train['primary_cleaner.output.concentrate_ag'] + 
                                          df_train['primary_cleaner.output.concentrate_pb'] )

final_output_concentrate_sum = (df_train['final.output.concentrate_au'] + 
                                df_train['final.output.concentrate_ag'] + 
                                df_train['final.output.concentrate_pb'] )

# %%
# все металлы
plt.figure(figsize=[12,8])

plt.hist(rougher_input_concentrate_sum, bins=100, label = 'Концетрация в сырье', alpha=.5)
plt.hist(rougher_output_concentrate_sum, bins=100, \
         label = 'Концетрация при черновой обработке', alpha=.5)
plt.hist(primary_cleaner_output_concentrate_sum, bins=100, \
         label = 'Концетрация после первой очистки', alpha=.5)
plt.hist(final_output_concentrate_sum, bins=100, \
         label = 'Концетрация в финальном результате', alpha=.5)

plt.xlim([0, 90])
plt.ylim([0, 1900])

plt.xlabel("Концентрация (вес) всех металлов на различных этапах флотации")
plt.ylabel("Количество одинаковых результатов")

plt.legend(loc='upper left', fontsize='xx-large')

plt.title("Гистограмма распределения концентрации всех металлов")
plt.show()

# %% [markdown]
# **Подитог**
#
# Как можем заметить общая концетрация металлов с каждым этапом увеличивается.
#
# В среднем с каждым этапом прирост концетрации металлов происходит на 10 у.е.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследована суммарная концентрация металлов на разных стадиях техпроцесса - отлично!

# %% [markdown]
# ### Вывод
# В результате изучена:
#
# - Концентрация металлов (Au, Ag, Pb) на разных этапах очистки;
# - Размер гранул сырья на обучающей и тестовой выборках;
# - Найдены выбросы и удалены;
# - Суммарная концентрация металлов на разных стадиях: в сырье, в черновом и финальном концентратах.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть промежуточный вывод по проекту - отлично!

# %% [markdown]
# # 3  Модель

# %% [markdown]
# ## 3.1 Напишите функцию для вычисления итоговой sMAPE

# %% [markdown]
# Нужно спрогнозировать сразу две величины:
# 1.	эффективность обогащения чернового концентрата rougher.output.recovery;
# 2.	эффективность обогащения финального концентрата final.output.recovery.
#
# Итоговая метрика складывается из двух величин:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# напишем функция для расчета sMAPE

def sMAPE(y_true,y_pred):
    error = np.mean(abs(y_true - y_pred)/((abs(y_true)+abs(y_pred))/2))*100
    return error

# %%
def final_sMAPE(sMAPE_rougher,sMAPE_final):
    return (0.25*sMAPE_rougher + 0.75*sMAPE_final)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть функции для частного и взвешенного `sMAPE` - супер!
# </div>

# %%
df_train.reset_index(drop= True, inplace=True)
df_test.reset_index(drop= True, inplace=True)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# А зачем тут снова сбрасываем индекс?

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Ну я же удалял выбросы, чтобы упорядочились индексы, не?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Окей, понял. В целом это необязатено, но как-то не пришло мне в голову про выбросы - спасибо, что пояснил:)

# %% [markdown]
# ## 3.2. Обучите разные модели. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.

# %% [markdown]
# ### Подготовим данные для тестовой выборки

# %%
columns_in_test = df_test.columns[1:] # Оставим все столбцы кроме data

# Для предсказания rougher.output.recovery используем данные из стобцов с названием признаков
# input(параметры сырья (rougher)) и state(тек шаг)
rougher_features_columns = columns_in_test[0:22] 


features_test_rougher = df_test[rougher_features_columns] # тестовые признаки для rougher.output.recovery
display(features_test_rougher)



final_features_columns = columns_in_test[22:]
features_test_final = df_test[final_features_columns] # тестовые признаки для final.output.recovery
features_test_final
# Out:
#       rougher.input.feed_au  rougher.input.feed_ag  rougher.input.feed_pb  \
# 0                  4.365491               6.158718               3.875727
# 1                  4.362781               6.048130               3.902537
# 2                  5.081681               6.082745               4.564078
# 3                  5.145949               6.084374               4.768124
# 4                  5.735249               6.165220               4.512346
# ...                     ...                    ...                    ...
# 4855               6.620245               5.992592               2.589242
# 4856               6.741324               6.158617               2.647185
# 4857               6.627458               6.015149               2.466127
# 4858               6.702243               6.097592               2.278955
# 4859               6.633002               5.908793               2.440899
#
#       rougher.input.feed_sol  rougher.input.feed_rate  \
# ...

# %%
df_test = df_test.merge(df_full[['date', 'rougher.output.recovery', 'final.output.recovery']], on='date')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В `test` добавили целевые признаки из `full`, используя дату как ключ при соединении - отлично!

# %%
target_test_rougher = df_test['rougher.output.recovery']
target_test_final = df_test['final.output.recovery']

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выделили признаки для обучения и целевые признаки - отлично!
# </div>

# %% [markdown]
# ### Подготовим данные для обучающей выборки

# %%
# Подготовка признаков для rougher.output.recovery

features_train_rougher = df_train[rougher_features_columns]
display(features_train_rougher)


# Подготовка признаков для final.output.recovery

features_train_final = df_train[final_features_columns]
features_train_final
# Out:
#        rougher.input.feed_au  rougher.input.feed_ag  rougher.input.feed_pb  \
# 0                   6.486150               6.100378               2.284912
# 1                   6.478583               6.161113               2.266033
# 2                   6.362222               6.116455               2.159622
# 3                   6.118189               6.043309               2.037807
# 4                   5.663707               6.060915               1.786875
# ...                      ...                    ...                    ...
# 13863               4.599524               5.822083               4.255546
# 13864               4.658125               5.844800               4.241564
# 13865               5.335862               6.091855               4.617558
# 13866               4.838619               6.121323               4.144989
# 13867               4.525061               5.970515               4.020002
#
#        rougher.input.feed_sol  rougher.input.feed_rate  \
# ...

# %%
target_train_rougher = df_train['rougher.output.recovery']
target_train_final = df_train['final.output.recovery']
target_train_final
# Out:
# 0        70.541216
# 1        69.266198
# 2        68.116445
# 3        68.347543
# 4        66.927016
#            ...
# 13863    64.054699
# 13864    68.643324
# 13865    73.755150
# 13866    69.049291
# 13867    67.002189
# Name: final.output.recovery, Length: 13868, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Вопрос:</b> правлиьный ли дали совет?
# </div>

# %%
# так посоветовала Светлана Медведева из яндекса (препод по проектам)
# target_train = df_train[['final.output.recovery','rougher.output.recovery']]

# %%
#так посоветовала Светлана из яндекса (препод по проектам)
# target_test = df_test[['final.output.recovery','rougher.output.recovery']]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ну, тут не столько совет, сколько один из способов работы с моделями. Ты сейчас делаешь два отдельных целевых признака и будешь под каждый из них учить модель - это ок. Тут делают двумерный таргет - соответственно, будет одна модель, которая сразу два целевых признака предсказывает. Тоже ок, но в целом не играет большой роли. Просто нужны будут другие функции для оценки результата.

# %%
custom_score = make_scorer(sMAPE,greater_is_better=False)# передаём функцию в качестве первого аргумент
# далее указываем greater_is_better = False/True, чтобы указать
# , что меньшее значение означает лучшее качество модели.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Пользовательский скорринг для кросс-валидации в порядке.

# %%
# В данном примере мы создали пайплайн из двух шагов: 
# стандартизации данных (масштабирование) StandardScaler и двух моделей обучения.
model_1 = make_pipeline(StandardScaler(),RandomForestRegressor(random_state=12345))  
model_2 = make_pipeline(StandardScaler(),DecisionTreeRegressor(random_state=12345))
#Мы не проводили отдельно стандартизацию данных и обучение модели, 
# а сделали это в рамках одного пайплайна.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Круто, что используешь `pipeline` в работе.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# При использовании моделей (кроме линейной регрессии) важно настроить параметр `random_state`, чтобы результаты работы над проектом были воспроизводимы при его перезапуске.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b></b> random_state добавил в модели
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Инициализация параметров для GridSearchCV
params_RF = {"randomforestregressor__n_estimators":range(11,40,20),
             "randomforestregressor__max_depth":range(1,10,2)}
params_DT= {"decisiontreeregressor__max_depth":range(1,10,4)}

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Оптимизация гиперпараметров выполнена немного формально: используя список в сетке параметров, мы исследуем только те значения, которые непосредственно находятся в этом списке - так шанс найти оптимальные гиперпараметры крайне низок. Вместо списка из нескольких значений стоит использовать последовательность `range()` - так шанс найти оптимальное значение выше.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# GridSearchCV принимает на вход модель
# список значений гиперпараметров 
# метрику оценки качества модели, и перебирает все возможные комбинации 


grid_rougher_forest = GridSearchCV(model_1,param_grid = params_RF,scoring=custom_score)
grid_final_forest = GridSearchCV(model_1,param_grid = params_RF,scoring=custom_score)
grid_rougher_DT = GridSearchCV(model_2,param_grid = params_DT,scoring=custom_score)
grid_final_DT = GridSearchCV(model_2,param_grid = params_DT,scoring=custom_score)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# При работе с `cross_val_score`, а также с `GridSearchCV` или `RandomizedSearchCV` есть несколько полезных действий, которые сделают нашу жизнь проще и лучше:)
#
# 1. Можно настроить параметр `n_jobs=-1`, чтобы для вычислений использовались все доступные ядра - это ускорит процесс.
# 2. Можно настроить параметр `verbose=10`, чтобы инструмент взаимодействовал с логом и выдавал сообщения о прогрессе обучения - так мы будем понимать, что процесс идёт, а не что, например, у нас упало ядро, и процесс завис.
# 3. Для кросс-валидации (параметр `cv`) вполне можно использовать и 3 фолда: мы немного потеряем в качестве, но процесс будет происходить гораздо быстрее. Для учебного проекта более чем достаточно:)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> возьму на заметку
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Пользуйся на здоровье:)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Тут ты заново делаешь переменную `param_grid` - нужно использовать уже созданную.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> я так делал чтобы видеть что и так и так работает
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# %%time
# проведем обучение для случайного леса
grid_rougher_forest.fit(features_train_rougher,target_train_rougher)
grid_final_forest.fit(features_train_final,target_train_final)

# для решающего дерева
grid_rougher_DT.fit(features_train_rougher,target_train_rougher)
grid_final_DT.fit(features_train_final,target_train_final)
# Out:
# Wall time: 2min 19s
# GridSearchCV(estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('decisiontreeregressor',
#                                         DecisionTreeRegressor(random_state=12345))]),
#              param_grid={'decisiontreeregressor__max_depth': range(1, 10, 4)},
#              scoring=make_scorer(sMAPE, greater_is_better=False))

# %%
# Выводим лучшую модель и ее параметры

print("Показатели модели Случайный лес для rougher")
print("Best model: ", grid_rougher_forest.best_estimator_)
print("Best parameters: ", grid_rougher_forest.best_params_)
print("Best score: ", -grid_rougher_forest.best_score_)
print("------------------------------------------------")
print("Показатели модели Случайный лес для final")
print("Best model: ", grid_final_forest.best_estimator_)
print("Best parameters: ", grid_final_forest.best_params_)
print("Best score: ", -grid_final_forest.best_score_)

print("------------------------------------------------")
print("Показатели модели Решаюшего дерева для rougher")
print("Best model: ", grid_rougher_DT.best_estimator_)
print("Best parameters: ", grid_rougher_DT.best_params_)
print("Best score: ", -grid_rougher_DT.best_score_)


print("------------------------------------------------")
print("Показатели модели Решаюшего дерева для final")
print("Best model: ", grid_final_DT.best_estimator_)
print("Best parameters: ", grid_final_DT.best_params_)
print("Best score: ", -grid_final_DT.best_score_)
# Out:
# Показатели модели Случайный лес для rougher
# Best model:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestregressor',
#                  RandomForestRegressor(max_depth=3, n_estimators=31,
#                                        random_state=12345))])
# Best parameters:  {'randomforestregressor__max_depth': 3, 'randomforestregressor__n_estimators': 31}
# Best score:  6.211890385697092
# ------------------------------------------------
# Показатели модели Случайный лес для final
# Best model:  Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestregressor',
#                  RandomForestRegressor(max_depth=3, n_estimators=11,
#                                        random_state=12345))])
# Best parameters:  {'randomforestregressor__max_depth': 3, 'randomforestregressor__n_estimators': 11}
# Best score:  9.036423965045046
# ------------------------------------------------
# ...

# %% [markdown]
# ### Выявим лучшую модель

# %%
best_score_rougher_forest = -grid_rougher_forest.best_score_
best_score_final_forest = -grid_final_forest.best_score_
best_score_rougher_DT = -grid_rougher_DT.best_score_
best_score_final_DT = -grid_final_DT.best_score_

# %%
print("rougher")
print("RandomForestRegressor",best_score_rougher_forest,"DecisionTree",best_score_rougher_DT)
print("final")
print("RandomForestRegressor",best_score_final_forest,"DecisionTree",best_score_final_DT)
# Out:
# rougher
# RandomForestRegressor 6.211890385697092 DecisionTree 6.711981243937759
# final
# RandomForestRegressor 9.036423965045046 DecisionTree 9.306678198207024

# %%
print(f'Финальный sMAPE для модели Случайный лес:',{final_sMAPE(best_score_rougher_forest,best_score_final_forest)})
# Out:
# Финальный sMAPE для модели Случайный лес: {8.330290570208057}

# %%
print(f'Финальный sMAPE для модели решающего дерева:',{final_sMAPE(best_score_rougher_DT,best_score_final_DT)})
# Out:
# Финальный sMAPE для модели решающего дерева: {8.658003959639707}

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# `final_sMAPE` также нужно посчитать и для решающего дерева, чтобы сравнивать идентичные метрики.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> мне казалось это очевидным так как выше показатели по решаюшему дереву были и по ним не считая понятно что они хуже.
#
# Готово
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Тут важно помнить, что ты аналитик, тем более - автор решения, поэтому то, что тебе кажется очень очевидным, может быть не столь очевидным для заказчика или коллеги, который будет изучать твой отчёт:) Поэтому чем меньше неопределённости - тем лучше для всех:)

# %% [markdown]
# ### Вывод:
# Лучшие результаты на тренировочной выборке показала модель RandomForest, ее отклонение минимально при следующих параметрах:
# 1. Для rougher:
# - Глубина : 3
# - Количество решающих деревьев: 31
#
# 2. Для final:
# - Глубина : 3
# - Количество решающих деревьев: 11
#
# Итоговое отклонение **sMAPE** составило: 8,33
# Это означает, что наша модель на основе RandomForestRegressor в среднем находит правильный ответ в 91,7% случаев.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Выбрали лучшую модель - отлично!

# %% [markdown]
# ### Проверим на тестовой выборке

# %% [markdown]
# ### Наименьшую ошибку мы получили при использовании рандомного леса

# %%
rogher_test = grid_rougher_forest.predict(features_test_rougher)

# %%
final_test = grid_final_forest.predict(features_test_final)

# %% [markdown]
# ### Отклонение на финальной sMAPE тестовой выборки

# %%
final_sMAPE(sMAPE(target_test_rougher,rogher_test),sMAPE(target_test_final,final_test))
# Out:
# 7.0699060102114775

# %% [markdown]
# Будем опираться на значения метрики final sMAPE, полученные на тестовых данных, так как они более точно отображают реальную способность модели к предсказанию.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Итоговую модель оценили на `test` - отлично!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Очень важно также проверить лучшую модель на адекватность, сравнив качество её предсказаний с качеством модели, которая предсказывала бы константу - вдруг окажется, что не было бы большого смысла заниматься созданием новых признаков, тюнингом и кросс-валидацией моделей, если можно было бы просто предсказывать среднее значение тренировочной выборки?
#
# В качестве константной модели можно использовать `DummyRegressor` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyRegressor.html) -  эта модель как раз создана для генерирования константных предсказаний.
#
# Важно, чтобы результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели - в противном случае наша модель является бесполезной, так как все наши усилия над проектом не принесли результата, а можель, просто предсказывющая среднее на `train`, делает нашу работу лучше.
#         </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Про дамми объясни простым языком пожалуйста и какую нибудь ссылку для чайников.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Идея в целом довольно простая: зачем нам модель, если мы всегда можем предсказывать среднее по `train` и не тратить время на разработку модели, тестирование, деплой и поддержание модели. Важно, чтобы наша модель была лучше константной модели - тогда все усилия были ненапрасны.
#
# Ссылок по этому вопросу я как-то не встречал, если честно - тут просто важно понять, зачем нам сравнение с константной моделью:)

# %% [markdown]
# ### Посчитаем при помощи DummyRegressor(strategy='mean') константное среднее значение:

# %%
dummy_regressor_rougher = DummyRegressor(strategy="mean")
dummy_regressor_rougher.fit(features_train_rougher,target_train_rougher) # обучаем на обучающей выборке
dummy_rougher_pred = dummy_regressor_rougher.predict(rogher_test) # предсказывает на тестовой
smape_dummy_rougher = sMAPE(target_test_rougher, dummy_rougher_pred) # расчитываем sMAPE

smape_dummy_rougher
# Out:
# 6.0994850213938046

# %%
dummy_regressor_final = DummyRegressor(strategy="median")
dummy_regressor_final.fit(features_train_final,target_train_final)
dummy_final_pred = dummy_regressor_final.predict(final_test)
smape_dummy_final = sMAPE(target_test_final, dummy_final_pred)
smape_dummy_final
# Out:
# 9.11555141611901

# %%
final = (smape_dummy_final + smape_dummy_rougher)/2
final
# Out:
# 7.607518218756407

# %% [markdown]
# ### Вывод
# - Наша модель прошла проверку на вменяемось, финальный sMAPE больше тестовой: 7.607518218756407
# - Итоговая модель построена на алгоритме RandomForest
# - Итоговое отклонение sMAPE на тренировочной выборке:8.330290570208057
# - Итоговое отклонение sMAPE на тестовой выборке: 7.0699060102114775

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Небольшой вывод по блоку - отлично!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Нужно дополнить константной моделью.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Учтено.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# По завершении проекта стоит сделать итоговый вывод: в него можно включить основные шаги проекта, а также ключевые выводы, полученные в ходе работы над ним.
#         </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Учтено.

# %% [markdown]
# ## ВЫВОДЫ:
#
#
#
# 1) Мы написали функции:
# - для вычисления sMAPE для каждой целевой переменной
# - для вычисления итогового значения sMAPE
#
# 2) Рассмотрели несколько видов моделей:
#
# - RandomForestRegressor
# - DecisionTree
#
# 3) Определили лучшую модель RandomForestRegressor со следующими гиперпараметрами:
# 3.1 для rougher.output.recovery
#
# - max_depth = 3
#
# - n_estimators = 31
#
# - random_state=12345
#
# 3.2 для final.output.recovery:
#
# - max_depth = 3
#
# - n_estimators = 11
#
# - random_state=12345
#
#
# 4) Мы получили модель, которая показала хорошие результаты на тестовой выборке с final sMAPE = 6.72608570644806.
#
# Это означает, что наша модель ошибается в среднем на 6.7% при предсказании коэффициента восстановления золота из золотосодержащей руды.
#
# Она будет помогать компании прогнозировать коэффициент восстановления золота и принимать более эффективные решения в процессе добычи и очистки золотосодержащей руды.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Артур, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с моделями также выполнена отлично: исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `GridSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец!
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.2.
#
# Артур, все замечания учтены - проект принят!
#
# Спасибо за хорошую работу над проектом, желаю успехов в дальнейшем обучении:)
